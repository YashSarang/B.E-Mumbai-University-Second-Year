# %% [markdown]
# Dated :  10th March 2022

# %% [markdown]
# # Experiment  No : 8

# %% [markdown]
# #Aim

# %% [markdown]
# ## Exploring Network Programming in Python

# %% [markdown]
# # Theory

# %% [markdown]
# * What is a socket ?
# * Syntax to create a socket
# * Diagram to illustrate the working of TCP Client Server Application.

# %% [markdown]
# ## Handwritten Theory

# %% [markdown]
# ![Scan 1 Page 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Tasks to be performed

# %% [markdown]
# * Execute the sample program in the document shared in the Google Classroom
# * Create a Chat Program between TCP Client & Server

# %% [markdown]
# # Program

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Conclusion

# %% [markdown]
# ![Scan 1 Page 2.jpg](data:image/jpeg;base64,...)
